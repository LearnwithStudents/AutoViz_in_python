# %% [markdown]
# # Visualize the Data of any size with single Line of code

# %% [markdown]
# # ===>Autoviz--------------->Automatically Visualize any dataset,

# %%
# !pip3 install autoviz

# %%
from autoviz.AutoViz_Class import AutoViz_Class

# %%
viz=AutoViz_Class()
# %matplotlib inline

# %%
import pandas as pd

# %%
df=pd.read_csv('events-US-1980-2021.csv')

# %%
df.head()
# Out:
#                                                       Name  ... Deaths
# 0         Southern Severe Storms and Flooding (April 1980)  ...      7
# 1                            Hurricane Allen (August 1980)  ...     13
# 2     Central/Eastern Drought/Heat Wave (Summer-Fall 1980)  ...   1260
# 3                            Florida Freeze (January 1981)  ...      0
# 4  Severe Storms, Flash Floods, Hail, Tornadoes (May 1981)  ...     20
#
# [5 rows x 6 columns]

# %%
filename='events-US-1980-2021.csv'

viz.AutoViz(filename,sep=',',depVar='Disaster',verbose=2,chart_format='html')
# Out:
# Shape of your Data Set loaded: (323, 6)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#   Printing upto 30 columns max in each category:
#     Numeric Columns : ['Total CPI-Adjusted Cost (Millions of Dollars)']
#     Integer-Categorical Columns: ['Begin Date', 'End Date', 'Deaths']
#     String-Categorical Columns: []
#     Factor-Categorical Columns: []
#     String-Boolean Columns: []
#     Numeric-Boolean Columns: []
#     Discrete String Columns: []
#     NLP text Columns: ['Name']
#     Date Time Columns: []
#     ID Columns: []
#     Columns that will not be considered in modeling: []
#     5 Predictors classified...
#         No variables removed since no ID or low-information variables found in data set
#
# ...
